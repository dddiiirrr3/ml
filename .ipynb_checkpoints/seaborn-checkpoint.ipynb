# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa = pd.read_csv('../data/fifa.csv', index_col='Date', parse_dates=True)
spot = pd.read_csv('../data/spotify.csv', index_col='Date', parse_dates=True)
flight = pd.read_csv('../data/flight_delays.csv', index_col='Month')
ign = pd.read_csv('../data/ign_scores.csv', index_col='Platform')
ins = pd.read_csv('../data/insurance.csv')
candy = pd.read_csv('../data/candy.csv', index_col='id')
iris = pd.read_csv('../data/iris.csv', index_col='Id')
iris_set = pd.read_csv('../data/iris_setosa.csv', index_col='Id')
iris_ver = pd.read_csv('../data/iris_versicolor.csv', index_col='Id')
iris_vir = pd.read_csv('../data/iris_virginica.csv', index_col='Id')

# %% [markdown]
# ## **line charts**

# %%
fifa
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
# set the width and height of the figure
plt.figure(figsize=(25,10))

# line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa);

# %%
spot
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
# set the width and height of the figure
plt.figure(figsize=(25,10))


sns.lineplot(data=spot[['Shape of You', 'Despacito']]);

# %% [markdown]
# ## **bar charts**

# %%
flight
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# set the width and height of the figure
plt.figure(figsize=(10,6))

# add title
plt.title('Average Arrival Delay for Spirit Airlines Flights, by Month')

# bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight.index, y=flight['AS'])

# add label
plt.ylabel('Arrival delay (in minutes)');

# %%
# set the width and height of the figure
plt.figure(figsize=(30,6))

# add title
plt.title('Average Arrival Delay for Spirit Airlines Flights, by Month')

# bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=ign.index, y=ign['Racing'])

# add label
plt.ylabel('score');

# %%
# Set the width and height of the figure
plt.figure(figsize=(8, 6))
# Bar chart showing average score for racing games by platform
sns.barplot(x=ign['Racing'], y=ign.index)
# Add label for horizontal axis
plt.xlabel("score")
# Add label for vertical axis
plt.title("Average Score for Racing Games, by Platform");

# %% [markdown]
# ## **heatmaps**

# %%
plt.figure(figsize=(14,7))

plt.title('Average Arrival Delay for Each Aorline, by Month')

# heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight, annot=True)

plt.xlabel('Airline');

# %%
ign
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
plt.figure(figsize=(14,7))

plt.title('Average score')

# heatmap showing average arrival delay for each airline by month
sns.heatmap(data=ign, annot=True)

plt.xlabel('games');

# %% [markdown]
# ## **scatter plots**

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.figure(figsize=(14,10))

sns.scatterplot(x=ins['bmi'], y=ins['charges']);

# %%
plt.figure(figsize=(14,10))
sns.regplot(x=ins['bmi'], y=ins['charges']);

# %%
plt.figure(figsize=(14,10))
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker', data=ins);

# %%
plt.figure(figsize=(14,10))
sns.swarmplot(x=ins['smoker'], y=ins['charges']);

# %%
candy
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
plt.figure(figsize=(14,10))
sns.scatterplot(x=candy['sugarpercent'], y=candy['winpercent']);

# %%
# Scatter plot w/ regression line showing the relationship between 'sugarpercent' and 'winpercent'
# Your code here
sns.regplot(x=candy['sugarpercent'], y=candy['winpercent']);

# %%
# Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate'
# Your code here
sns.scatterplot(x=candy['pricepercent'], y=candy['winpercent'], hue=candy['chocolate']);

# %%
sns.lmplot(x='pricepercent', y='winpercent', hue='chocolate', data=candy);

# %%
# Scatter plot showing the relationship between 'chocolate' and 'winpercent'
# Your code here
sns.swarmplot(x=candy['chocolate'], y=candy['winpercent']);

# %% [markdown]
# ## **distributions**

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
# histogram
sns.distplot(a=iris['Petal Length (cm)'], kde=False);

# %%
# kde plot (kernel density estimate)
sns.kdeplot(data=iris['Petal Length (cm)'], shade=True)

# %%
# 2d kde
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind='kde');

# %%
iris_set.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
# Histograms for each species
sns.distplot(a=iris_set['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend();

# %%
# Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"
sns.set_style("dark")
# KDE plots for each species
sns.kdeplot(data=iris_set['Petal Length (cm)'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver['Petal Length (cm)'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir['Petal Length (cm)'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species");
