# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
df_train = pd.read_csv('../data/home-data-for-ml-course/train.csv')
df_test = pd.read_csv('../data/home-data-for-ml-course/test.csv')
df_sample = pd.read_csv('../data/home-data-for-ml-course/sample_submission.csv')

# %%
features = ['OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'GrLivArea', 'FullBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'YrSold']

# %%
y_train = df_train.SalePrice

# %%
X_train = df_train[features]

# %%
X_test = df_test[features]

# %%
y_test = df_sample['SalePrice']

# %%
X_test
# Out:
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  GrLivArea  FullBath  \
# 0               5            6       1961          1961        896         1
# 1               6            6       1958          1958       1329         1
# 2               5            5       1997          1998       1629         2
# 3               6            6       1998          1998       1604         2
# 4               8            5       1992          1992       1280         2
# ...           ...          ...        ...           ...        ...       ...
# 1454            4            7       1970          1970       1092         1
# 1455            4            5       1970          1970       1092         1
# 1456            5            7       1960          1996       1224         1
# 1457            5            5       1992          1992        970         1
# 1458            7            5       1993          1994       2000         2
#
# ...

# %%
y_test
# Out:
# 0       169277.052498
# 1       187758.393989
# 2       183583.683570
# 3       179317.477511
# 4       150730.079977
#             ...
# 1454    167081.220949
# 1455    164788.778231
# 1456    219222.423400
# 1457    184924.279659
# 1458    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, X_train, X_test, y_train, y_test):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(X_train, y_train)
    preds_val = model.predict(X_test)
    mae = mean_absolute_error(y_test, preds_val)
    return(mae)

# %%
maes = []
for max_leaf_nodes in range(3, 1000):
    my_mae = get_mae(max_leaf_nodes, X_train, X_test, y_train, y_test)
    maes = maes + [my_mae]
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
best_tree_size = maes.index(min(maes))+2
print(best_tree_size)
# Out:
# Max leaf nodes: 3  		 Mean Absolute Error:  51203
# Max leaf nodes: 4  		 Mean Absolute Error:  51993
# Max leaf nodes: 5  		 Mean Absolute Error:  51997
# Max leaf nodes: 6  		 Mean Absolute Error:  51482
# Max leaf nodes: 7  		 Mean Absolute Error:  51014
# Max leaf nodes: 8  		 Mean Absolute Error:  50685
# Max leaf nodes: 9  		 Mean Absolute Error:  50748
# Max leaf nodes: 10  		 Mean Absolute Error:  50787
# Max leaf nodes: 11  		 Mean Absolute Error:  50589
# Max leaf nodes: 12  		 Mean Absolute Error:  50910
# Max leaf nodes: 13  		 Mean Absolute Error:  51949
# Max leaf nodes: 14  		 Mean Absolute Error:  51613
# Max leaf nodes: 15  		 Mean Absolute Error:  51429
# Max leaf nodes: 16  		 Mean Absolute Error:  51103
# Max leaf nodes: 17  		 Mean Absolute Error:  51071
# Max leaf nodes: 18  		 Mean Absolute Error:  50873
# Max leaf nodes: 19  		 Mean Absolute Error:  51037
# Max leaf nodes: 20  		 Mean Absolute Error:  50760
# Max leaf nodes: 21  		 Mean Absolute Error:  50601
# ...
